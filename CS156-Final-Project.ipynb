# %% [markdown]
# # CS156 Final Project

# %% [markdown]
# ### Problem Definition

# %% [markdown]
# ### Solution Specification

# %% [markdown]
# ### Testing and Analysis

# %% [markdown]
# ### References

# %% [markdown]
# ### Appendices
# #### The Code

# %% [markdown]
# ####LO Applications
#
# * #cs156-overfitting
# * #cs156-classification
# * #cs156-unsupervisedlearning
# * #cs156-
# * #cs156-
#
# #### HC Applications
#
# * #variables
# * #probability
# * #algorithms
# * #--
# * #--
