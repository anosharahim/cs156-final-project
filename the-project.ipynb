# %% [markdown]
# # CS156 Final Project

# %% [markdown]
# ## Problem Definition
#
# The Google QuickDraw Dataset is a collection of 50M vector sketches across 345 categories. Quick, Draw! has many images that are not good examples of a given category. Sketch-RNN can be used here to separate good images of a certain class from bad images.
#
#
# bad drawings from good drawings -- how to tell?
# classify bad drawings from good drawings

# %% [markdown]
# ## Solution Specification
#
# Using Sketch-RNN -- why this approach is superior to alternatives?

# %% [markdown]
# ## Testing and Analysis
# give insight into the empirical performance of your method ---

# %% [markdown]
# ## References
# *   About Sketch-RNN: https://github.com/magenta/magenta/tree/main/magenta/models/sketch_rnn#pre-trained-models
# *   how to load pre-trained Sketch-RNN models: https://github.com/magenta/magenta-demos/blob/main/jupyter-notebooks/Sketch_RNN.ipynb
# *   good flamingoes, bad flamingoes: http://colinmorris.github.io/blog/bad_flamingos
#
#
# *   AI-sketcher: https://idvxlab.com/papers/2019AAAI_Sketcher_Cao.pdf
#
# *   List item
# *   List item
#
#
# *   List item

# %% [markdown]
# ## Appendices
# ### The Code

# %% [markdown]
# ###LO Applications
#
# * #cs156-neuralnetworks
# * #cs156-graphicalmodels
# * #cs156-
# * #cs156-
# * #cs156-
#
# ### HC Applications
#
# * #variables
# * #probability
# * #algorithms
# * #--
# * #--
